# %% [markdown]
# # SQL - Analytics Project with Olist Brazilian E-commerce

# %% [markdown]
# # 1. Connection to the Database

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import create_engine
from sqlalchemy.engine import URL
import dotenv
import os  

dotenv.load_dotenv()

USERNAME = os.getenv("USERNAME")
PASSWORD = os.getenv("PASSWORD")
HOST = os.getenv("HOST")
DATABASE = os.getenv("DATABASE")

url = URL.create(
    drivername= "postgresql+psycopg2",
    username=USERNAME,
    password=PASSWORD,
    host=HOST,
    port=5432,
    database=DATABASE,
    query={"sslmode": "require"}
)

engine = create_engine(url)


test_conection = pd.read_sql_query("select * from olist_geolocation limit 5", engine)

print(test_conection.head())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 17
#      14 HOST = os.getenv("HOST")
#      15 DATABASE = os.getenv("DATABASE")
# ---> 17 url = URL.create(
#      18     drivername= DRIVERNAME,
#      19     username=USERNAME,
#      20     password=PASSWORD,
#      21     host=HOST,
#      22     port=5432,
#      23     database=DATABASE,
#      24     query={"sslmode": "require"}
#      25 )
#      27 engine = create_engine(url)
#      30 test_conection = pd.read_sql_query("select * from olist_geolocation limit 5", engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sqlalchemy\engine\url.py:209, in URL.create(cls, drivername, username, password, host, port, database, query)
#     152 @classmethod
#     153 def create(
#     154     cls,
#    (...)    161     query: Mapping[str, Union[Sequence[str], str]] = util.EMPTY_DICT,
#     162 ) -> URL:
#     163     """Create a new :class:`_engine.URL` object.
#     164
#     165     .. seealso::
#    (...)    205
#     206     """
#     208     return cls(
# --> 209         cls._assert_str(drivername, "drivername"),
#     210         cls._assert_none_str(username, "username"),
#     211         password,
#     212         cls._assert_none_str(host, "host"),
#     213         cls._assert_port(port),
#     214         cls._assert_none_str(database, "database"),
#     215         cls._str_dict(query),
#     216     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sqlalchemy\engine\url.py:230, in URL._assert_str(cls, v, paramname)
#     227 @classmethod
#     228 def _assert_str(cls, v: str, paramname: str) -> str:
#     229     if not isinstance(v, str):
# --> 230         raise TypeError("%s must be a string" % paramname)
#     231     return v
#
# TypeError: drivername must be a string
