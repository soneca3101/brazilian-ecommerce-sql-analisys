# %% [markdown]
# # SQL - Analytics Project with Olist Brazilian E-commerce

# %% [markdown]
# # 1. Connection to the Database

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import dotenv
import os
import psycopg2

dotenv.load_dotenv(override=True)

DATABASE_URL = os.getenv("DATABASE_URL")

url = DATABASE_URL


engine = psycopg2.connect(DATABASE_URL)


test_conection = pd.read_sql_query("select * from olist_geolocation limit 5", engine)

print(test_conection.head())

# %%
import os
from dotenv import load_dotenv, find_dotenv

# find_dotenv() localiza o arquivo automaticamente e passa o caminho para o load_dotenv
caminho_env = find_dotenv()

# Carrega as variáveis e sobrescreve qualquer cache antigo
load_dotenv(caminho_env, override=True)

# Debug: Verifique se ele achou o arquivo!
print(f"O arquivo .env foi encontrado em: {caminho_env}")

# Continua com seu código...
db_url = os.getenv("DATABASE_URL")

# %%
import os

# Pede para o Python listar todos os arquivos que ele está vendo na pasta atual
arquivos = os.listdir()
print(arquivos)
# Out:
# ['brazilian_ecommerce-sql_analisys..ipynb', 'db.env']
